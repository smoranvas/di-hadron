# %%
import jupyterthemes as jt
from jupyterthemes.stylefx import set_nb_theme

set_nb_theme('chesterish')
# Out:
# <style> div#notebook {
#  font-family: sans-serif;
#  font-size: 13pt;
#  line-height: 170%;
#  color: #cdd2e9;
#  -webkit-font-smoothing: antialiased !important;
#  padding-top: 25px !important;
# }
# body,
# div.body {
#  font-family: sans-serif;
#  font-size: 13pt;
#  color: #a2b0c7;
#  background-color: #1a2028;
#  background: #1a2028;
#  -webkit-font-smoothing: antialiased !important;
# }
# body.notebook_app {
#  padding: 0;
#  background-color: #1a2028;
#  background: #1a2028;
#  padding-right: 0px !important;
#  overflow-y: hidden;
# }
# a {
#  font-family: sans-serif;
#  color: #a2b0c7;
#  -webkit-font-smoothing: antialiased !important;
# }
# a:hover,
# a:focus {
#  color: #dbe1ea;
#  -webkit-font-smoothing: antialiased !important;
# }
# div#maintoolbar {
#  position: absolute;
#  width: 90%;
#  margin-left: -10%;
#  padding-right: 8%;
#  float: left;
#  background: transparent !important;
# }
# #maintoolbar {
#  margin-bottom: -3px;
#  margin-top: 0px;
#  border: 0px;
# ...

# %%
#load libraries 
import time,os
from matplotlib.offsetbox import AnchoredText
import sys,pandas as pd, matplotlib , matplotlib.pyplot as plt, matplotlib.lines , numpy as np,cupy as cp, math, pylab
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
#import cudf
#import ROOT
#from ROOT import TFile

#import root_pandas

#from toggle_cell import hide_cell 
import uproot3
# %matplotlib inline

#presets for plot style
from scipy.constants import golden
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (7, 7/golden),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
pylab.rcParams.update(params)

viridis = cm.get_cmap('viridis', 12)
inferno = cm.get_cmap('inferno', 12)
autumn = cm.get_cmap('autumn', 12)

#physical_devices = tf.config.list_physical_devices('GPU')
#tf.config.experimental.set_memory_growth(physical_devices[0], True)
#tf.config.experimental.set_memory_growth(physical_devices[1], True)
rc = plt.rc
rc('text', usetex=False)
import matplotlib as mpl
rc('font', family='serif')
rc('text', usetex=False)
rc('font', size=18)
rc('xtick', labelsize=18)
rc('ytick', labelsize=18)
rc('legend', fontsize=18)
import root_pandas,glob

import gc

def read_n(pattern, n):
    if not '*' in pattern:
        a = root_pandas.read_root(pattern,chunksize=int(n))
    else:
        a = root_pandas.read_root(glob.glob(pattern),chunksize=int(n))
    for b in a:
        del a
        print(n)
        return b

from scipy.optimize import curve_fit

image_dir='images'

import misc_util

import jupyterthemes as jt
import jupyterthemes as jt
from jupyterthemes.stylefx import set_nb_theme

set_nb_theme('chesterish')

plt.rcParams['figure.facecolor']='white'
plt.rcParams['savefig.facecolor']='white'
plt.rcParams['savefig.bbox']='tight'

import ROOT
# Out:
# Welcome to JupyROOT 6.22/09

# %%
import os

dfs = {'data':None, 'mc':None}

path = '/home/seba/di-hadron/data/pb/'
files = os.listdir(path)
maxfiles = 1
for i,file in enumerate(files):
    if i >= maxfiles: 
        break
    print(path+file)
    df = root_pandas.read_root(path + file,'ntuple_data')
    print(df)
    if dfs['data'] is None:
        dfs['data'] = df
    else :
        dfs['data'] = pd.concat([dfs['data'],df])
# Out:
# /home/seba/di-hadron/data/pb/N_clas_41775_00.pass2.root
#                       Q2        Nu        Xb           vxe       vye  \
# entry subentry
# 0     0         1.721132  3.326628  0.275709  7.166050e-09 -0.081970
# 1     0         1.224915  4.055211  0.160966  0.000000e+00 -0.410697
# 2     0         1.609808  2.632009  0.325933  7.386633e-01  0.426468
#       1         1.609808  2.632009  0.325933  7.386633e-01  0.426468
#       2         1.609808  2.632009  0.325933  7.386633e-01  0.426468
# ...                  ...       ...       ...           ...       ...
# 8706  0         1.767917  2.823481  0.333671  8.195916e-01 -0.473191
# 8707  0         2.163107  3.090410  0.372995  3.944074e-01 -0.227711
#       1         2.163107  3.090410  0.372995  3.944074e-01 -0.227711
# 8709  0         1.373101  3.225868  0.226828  0.000000e+00 -0.141741
#       1         1.373101  3.225868  0.226828  0.000000e+00 -0.141741
#
# ...

# %%
    
path = '/home/sebouh/di-hadron/simul/Pb/'
files = os.listdir(path)
maxfiles = 1
for i,file in enumerate(files):
    if i >= maxfiles: 
        break
    df = root_pandas.read_root(path + file,'ntuple_sim')
    if dfs['mc'] is None:
        dfs['mc'] = df
    dfs['mc'] = pd.concat([dfs['mc'],df])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-1beae505f32b> in <module>
#       5     if i >= maxfiles:
#       6         break
# ----> 7     df = root_pandas.read_root(path + file,'ntuple_sim')
#       8     if dfs['mc'] is None:
#       9         dfs['mc'] = df
#
# ~/di-hadron/root_pandas.py in read_root(filename, treename, N)
#      30                 raise Exception("error: treename must be specified; more than one tree in " + filename)
#      31
# ---> 32         df = f[treename].pandas.df(entrystop=N)
#      33     return df
#      34 if __name__=='__main__':
#
# ~/.local/lib/python3.8/site-packages/uproot3/_connect/_pandas.py in df(self, branches, namedecode, entrystart, entrystop, flatten, flatname, awkwardlib, cache, basketcache, keycache, executor, blocking)
# ...

# %%
for key in 'mc'.split():
    df = dfs[key].query('abs(pid)==211')
    plt.hist(df.eval('T4'),histtype='step', bins=100, range=(-2,2))
    plt.hist(df.query('abs(mc_pid)==211').eval('T4'),histtype='step', bins=100, range=(-2,2))
    
plt.gca().set_yscale('log')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-8d85d4ff7cb3> in <module>
#       1 for key in 'mc'.split():
# ----> 2     df = dfs[key].query('abs(pid)==211')
#       3     plt.hist(df.eval('T4'),histtype='step', bins=100, range=(-2,2))
#       4     plt.hist(df.query('abs(mc_pid)==211').eval('T4'),histtype='step', bins=100, range=(-2,2))
#       5
#
# AttributeError: 'NoneType' object has no attribute 'query'

# %%
dfs
# Out:
# {'data':                       Q2        Nu        Xb           vxe       vye  \
#  entry subentry
#  0     0         1.721132  3.326628  0.275709  7.166050e-09 -0.081970
#  1     0         1.224915  4.055211  0.160966  0.000000e+00 -0.410697
#  2     0         1.609808  2.632009  0.325933  7.386633e-01  0.426468
#        1         1.609808  2.632009  0.325933  7.386633e-01  0.426468
#        2         1.609808  2.632009  0.325933  7.386633e-01  0.426468
#  ...                  ...       ...       ...           ...       ...
#  8706  0         1.767917  2.823481  0.333671  8.195916e-01 -0.473191
#  8707  0         2.163107  3.090410  0.372995  3.944074e-01 -0.227711
#        1         2.163107  3.090410  0.372995  3.944074e-01 -0.227711
#  8709  0         1.373101  3.225868  0.226828  0.000000e+00 -0.141741
#        1         1.373101  3.225868  0.226828  0.000000e+00 -0.141741
#
#                        vze  SectorEl  TargType       Pex       Pey  ...  \
# ...

# %%
f = ROOT.TFile('/home/sebouh/di-hadron/simul/Pb/1.root')
sim = f.Get('ntuple_sim')

# %%
f = ROOT.TFile('/home/seba/di-hadron/data/pb/N_clas_41775_00.pass2.root')
data = f.Get('ntuple_data')
data

# %%
c1 = ROOT.TCanvas()
f = ROOT.TFile('/home/sebouh/di-hadron/simul/Pb/1.root')
sim = f.Get('ntuple_sim')
sim.Draw('T4>>h(100,-5,5)', "abs(pid)==211 && Zh>0.5")
sim.Draw('T4', "abs(pid)==211 && abs(mc_pid) ==211 && Zh>0.5", "SAME")
c1.SetLogy()
c1.Draw()

# %%
f = ROOT.TFile('/home/seba/di-hadron/data/pb/N_clas_41775_00.pass2.root')
data = f.Get('ntuple_data')
data.Draw('T4>>g(100,-5,5)',"","")
c1.SetLogy()
c1.Draw()
#c1.SetLogy()

# %%
c1.Draw()
