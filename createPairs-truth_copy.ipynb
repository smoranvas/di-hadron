# %%
import ROOT
from ROOT import TFile
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import copy
import pandas as pd 
import time
from os import listdir
# Out:
# Welcome to JupyROOT 6.22/09

# %%
class particle:
    def __init__(self, pid, fourvector, virtual_photon,ThetaPQ ):## '__init__' is the constructor of the class
        self.virtual_photon = virtual_photon
        Nu = virtual_photon.E()   ##components of a 4-vector TLorentzVector
        Q2 = -virtual_photon.M2() ## magnitud squared of a 4-vector TLorentzVector
        self.proton = ROOT.TLorentzVector()  ## proton is an attribute of the class 'particle' just created.
        self.proton.SetPxPyPzE(0,0,0, 0.938)  ## SetPxPyPzE is just a function of ROOT
        self.W = (virtual_photon + self.proton).M() ##.M() return the magnitud of a TLorentzVector [W2=(p+q)2]
        incoming_e = ROOT.TLorentzVector()
        incoming_e.SetPxPyPzE(0,0,5.014,5.014)
        part1 = virtual_photon.Vect().Cross(incoming_e.Vect()).Unit()
        part2 = virtual_photon.Vect().Cross(fourvector.Vect()).Unit()
        sign  = np.sign(part1.Dot(fourvector.Vect())) ## sign returns -1 0 or 1 if the input is negative, zero or positive.
        self.PhiPQ = sign*np.arccos(part1.Dot(part2))
        photon_pz = np.sqrt(Nu*Nu+Q2) #direction is positive by definition
        self.bcm = photon_pz/(Nu + 0.938)#photon-nucleon center-of-mass velocity 
        self.ycm = 0.5*np.log(( 1+self.bcm)/(1-self.bcm)) #photon-nucleon center-of-mass rapidity
        self.LorentzVector = fourvector #hadron four-vector. 4-vector is an input of this class
        self.PhiLab = self.LorentzVector.Phi()
        self.ThetaLab = self.LorentzVector.Theta()
        self.E = self.LorentzVector.E() #energy in lab frame
        self.vector = self.LorentzVector.Vect()
        self.Pt = self.vector.Perp(virtual_photon.Vect().Unit()) #pT with respect to photon direction
        self.Pl  = self.vector.Dot(virtual_photon.Vect().Unit()) #pL with respect to photon direction (in lab frame)
        self.y =  0.5*np.log( (self.E+self.Pl)/(self.E-self.Pl)) #rapidity in lab frame
        self.mT = np.sqrt(self.LorentzVector.M2() + self.Pt*self.Pt)
        self.y_star = self.y - self.ycm
        self.Pl_star = self.mT*np.sinh(self.y_star) # y is rapidity
        self.Xf = 2.0*self.Pl_star/self.W 
        self.pid = pid
        self.Zh = self.E/Nu
        self.ThetaPQ = np.arctan(self.Pt/self.Pl)
        self.P = np.sqrt(self.LorentzVector.Px()**2+self.LorentzVector.Py()**2+self.LorentzVector.Pz()**2)
        #self.Nphe=Nphe
        #self.deltaZ=deltaZ
        #self.fidCut=fid
        
    def redefine(self, new_virtual_photon):
        incoming_e = ROOT.TLorentzVector()
        incoming_e.SetPxPyPzE(0,0,5.014,5.014)
        part1 = new_virtual_photon.Vect().Cross(incoming_e.Vect()).Unit()
        part2 = new_virtual_photon.Vect().Cross(self.LorentzVector.Vect()).Unit()
        sign  = np.sign(part1.Dot(self.LorentzVector.Vect()))
        self.PhiPQ = sign*np.arccos(part1.Dot(part2)) 
        self.Pt = self.LorentzVector.Vect().Perp(new_virtual_photon.Vect().Unit()) #pT with respect to photon direction
        self.Pl  = self.LorentzVector.Vect().Dot(new_virtual_photon.Vect().Unit()) #pL with respect to photon direction (in lab frame)
        self.y =  0.5*np.log( (self.E+self.Pl)/(self.E-self.Pl)) #rapidity in lab frame
        self.ThetaPQ = np.arctan(self.Pt/self.Pl)
        self.virtual_photon = new_virtual_photon
        
        return
        
    def print_properties(self):
        print ('Hello, let me introduce myself, i am particle pid = ' , self.pid, ' with index ', self.index, ', from event  #', self.ievt, ' Nu and W', self.Nu, ' ' , self.W)
        print ('zh = ', self.Zh, ' phi_pq= ', self.PhiPQ, ' theta_pq=' , self.ThetaPQ, 'E = ', self.E, ' xf', self.Xf,'Pt ', self.Pt, ' Pl= ', self.Pl, ' rapidity=' ,  self.y)
        print ('pid = ' , self.pid)

# %%
def getDataframes(filename, Target=1,maxevents=1e9,tree_name='ntuple_data',isMC=False, include_truth=False, include_recon_fail = False):
    dphi = np.array([])  
    
    ParticlesFromPrevious = []
    
    try:
        myfile = TFile.Open('%s'%filename,'READ')
        myfile.Print()
    except:
        print("could not open file")
    mytree = myfile.Get(tree_name)
        
    print (filename, ' has ', mytree.GetEntries(), ' entries')
    
    tupla = {}  
    tupla['dphi'] = [] 
    tupla['dphi_lab'] = []
    tupla['drap'] = []
    tupla['h1_z'] = [] 
    tupla['h2_z'] = []
    tupla['h1_cm_pt'] = []
    tupla['h2_cm_pt'] = []
    tupla['h1_xf'] = []
    tupla['h2_xf'] = []
    tupla['h1_rap'] = []
    tupla['ycm'] = []
    tupla['h2_rap'] = []
    tupla['h1_pid'] = []
    tupla['h2_pid'] = []
    tupla['h1_cm_ph'] = []
    tupla['h2_cm_ph'] = []
    tupla['h1_cm_th'] = []  
    tupla['h2_cm_th'] = []  
    tupla['pair_mass'] = []
    tupla['pair_pt'] = []
    tupla['mx_eh1h2x'] = []
    tupla['mx_eh1x'] = []
    tupla['mx_eh2x'] = []
    tupla['t']  = []
    tupla['Q2'] = [] 
    tupla['nu'] = []
    tupla['W']  = []
    tupla['x'] = []
    tupla['u']  = []
    tupla['h1_ph'] = []
    tupla['h1_th'] = []
    tupla['h2_ph'] = []
    tupla['h2_th'] = []
    
    #mc truth variables (added by Sebouh)
    if include_truth:
        tupla['dphi_truth'] = [] 
        tupla['dphi_lab_truth'] = []
        tupla['drap_truth'] = []
        tupla['h1_truth_z'] = [] 
        tupla['h2_truth_z'] = []
        tupla['h1_truth_cm_pt'] = []
        tupla['h2_truth_cm_pt'] = []
        tupla['h1_truth_xf'] = []
        tupla['h2_truth_xf'] = []
        tupla['h1_truth_rap'] = []
        tupla['ycm_truth'] = []
        tupla['h2_truth_rap'] = []
        tupla['h1_truth_pid'] = []
        tupla['h2_truth_pid'] = []
        tupla['h1_truth_cm_ph'] = []
        tupla['h2_truth_cm_ph'] = []
        tupla['h1_truth_cm_th'] = []  
        tupla['h2_truth_cm_th'] = []  
        tupla['pair_mass_truth'] = []
        tupla['pair_pt_truth'] = []
        tupla['mx_eh1h2x_truth'] = []
        tupla['mx_eh1x_truth'] = []
        tupla['mx_eh2x_truth'] = []
        tupla['t_truth']  = []
        tupla['Q2_truth'] = [] 
        tupla['nu_truth'] = []
        tupla['W_truth']  = []
        tupla['x_truth'] = []
        tupla['u_truth']  = []
        tupla['h1_truth_ph'] = []
        tupla['h1_truth_th'] = []
        tupla['h2_truth_ph'] = []
        tupla['h2_truth_th'] = []
    
    
    
    ## here we create another dictionary
    tupla_mix = {}
    tupla_mix['dphi'] = []
    tupla_mix['dphi_lab'] = []
    tupla_mix['drap'] = []
    tupla_mix['h1_z'] = []
    tupla_mix['h2_z'] = []
    tupla_mix['h1_cm_pt'] = []
    tupla_mix['h2_cm_pt'] = []
    tupla_mix['h1_xf'] = []
    tupla_mix['h2_xf'] = []
    tupla_mix['h1_rap'] = []
    tupla_mix['ycm'] = []
    tupla_mix['h2_rap'] = []
    tupla_mix['h1_pid'] = []
    tupla_mix['h2_pid'] = []
    tupla_mix['h1_cm_ph']   = []
    tupla_mix['h2_cm_ph'] = []
    tupla_mix['h1_cm_th'] = []
    tupla_mix['h2_cm_th'] = []
    tupla_mix['pair_mass'] = []
    tupla_mix['pair_pt'] = []
    tupla_mix['mx_eh1h2x'] = []
    tupla_mix['mx_eh1x'] = []
    tupla_mix['mx_eh2x'] = []
    tupla_mix['t']  = []
    tupla_mix['Q2'] = []
    tupla_mix['nu'] = []
    tupla_mix['W']  = []
    tupla_mix['x'] = []
    tupla_mix['u']  = []
    tupla_mix['h1_ph'] = []
    tupla_mix['h1_th'] = []
    tupla_mix['h2_ph'] = []
    tupla_mix['h2_th'] = []
    tupla_mix['dphi_norot'] = [] #save variable before rotation to new virtual photon frame
    tupla_mix['h2_cm_ph_norot'] = [] #save variable before rotation to new virtual photon frame
    tupla_mix['h2_cm_th_norot'] = [] #save variable before rotation to new virtual photon frame
    
    ## here we create another dictionary
    tupla_trigger = {}
    tupla_trigger['h1_pid'] = []
    tupla_trigger['h1_xf'] = []
    tupla_trigger['h1_xf_default'] = []
    tupla_trigger['h1_z']  = []
    tupla_trigger['h1_cm_pt'] = []
    tupla_trigger['h1_rap']  = []
    tupla_trigger['ycm'] = []
    tupla_trigger['Q2'] = []
    tupla_trigger['x'] = []
    tupla_trigger['nu'] = []
    tupla_trigger['W'] = []
    tupla_trigger['h1_cm_ph'] = []
    tupla_trigger['h1_cm_th'] = []
    tupla_trigger['TargType'] = []
    tupla_trigger['missing_mass'] = []
    tupla_trigger['h1_ph'] = []
    tupla_trigger['h1_th'] = []
    
    if include_truth:
        mytree.mc_W = 0.938**2+mytree.mc_Nu*0.938*2-mytree.mc_Q2
    
    start = time.time()
    print('About to loop over ', mytree.GetEntries() , ' entries')
    for ievt  in range(mytree.GetEntries()):
        #print('evnt: ',ievt, 'len ParticlesFromPrevious ', (len(ParticlesFromPrevious)))
        
        #for kkk  in range (len(ParticlesFromPrevious)):
        #    print('evnt',ievt, 'ParticlesFromPrevious, pid:', ParticlesFromPrevious[kkk].pid, 'zh: ', ParticlesFromPrevious[kkk].Zh, 'W: ',ParticlesFromPrevious[kkk].W )

        mytree.GetEntry(ievt) 
        
        #skip event if it doesn't pass recon nor generated
        if not (mytree.W>2.05 and mytree.Q2>1.0) and not (include_recon_fail and mytree.mc_W>2.05 and mytree.mc_Q2>1.0): continue
        
        if ievt>maxevents: break        
        if(mytree.TargType==1):
            TargType=1
        elif(mytree.TargType==2):
            TargType=2
        else:
            TargType=0
        #print (TargType,  ' ' , Target)
        if not(isMC) and (TargType!=Target): continue ## 'Target' is a argument of this function
                
        #print('PASO all cuts')
        W = mytree.W
        Nu = mytree.Nu
        #get electron momentum:
        Pe = np.sqrt(mytree.Pex*mytree.Pex + mytree.Pey*mytree.Pey+ mytree.Pez*mytree.Pez)
        scattered_e = ROOT.TLorentzVector()
        scattered_e.SetPxPyPzE(mytree.Pex, mytree.Pey, mytree.Pez, Pe)
        
        incoming_e = ROOT.TLorentzVector()
        incoming_e.SetPxPyPzE(0,0,5.014,5.014)
        virtual_photon  = incoming_e - scattered_e 
        virtual_photon_unitvector = virtual_photon.Vect().Unit()
        proton = ROOT.TLorentzVector()
        proton.SetPxPyPzE(0,0,0, 0.938)
        
        if include_truth:
            Nu_truth = mytree.mc_Nu
            Pe_truth = np.sqrt(mytree.mc_Pex*mytree.mc_Pex + mytree.mc_Pey*mytree.mc_Pey+ mytree.mc_Pez*mytree.mc_Pez)
            scattered_e_truth = ROOT.TLorentzVector()
            scattered_e_truth.SetPxPyPzE(mytree.mc_Pex, mytree.mc_Pey, mytree.mc_Pez, Pe_truth)
            virtual_photon_truth  = incoming_e - scattered_e_truth 
            virtual_photon_unitvector_truth = virtual_photon_truth.Vect().Unit()
        
        
        ## for each event the particles are saved in the 'particles' list.        
        particles = []  ## this is how you define a list in python, this is created for each event
        #print (' Entering main loop over particles')
        for i in range(len(mytree.pid)):
            #print(mytree.pid[i])
            ## when the condition is true the 'continue' statement
            ## takes me to the next iteration of the loop
            if (abs(mytree.pid[i]) !=211 and mytree.pid[i]!=2212): continue 
                            
            ## aplying the rest of cuts:
            if ( mytree.FidCheckCutPiPlus[i]==False or abs(mytree.deltaZ[i])>=3.0 or mytree.P[i]<0.2 or mytree.ThetaLab[i]<10 or mytree.ThetaLab[i]>120 ):    continue
            if ( mytree.pid[i]==-211 and (mytree.ThetaLab[i]>90 or mytree.ThetaLab[i]<25) ):    continue                
            if ( mytree.pid[i]==-211 and mytree.ThetaLab[i]>40 and mytree.P[i]<0.2  ):    continue                
            if ( mytree.pid[i]==-211 and mytree.ThetaLab[i]<40 and mytree.P[i]<0.5  ):    continue 
            if ( mytree.pid[i]==211  and mytree.P[i]>=2.7 and (mytree.Nphe[i]<15 or mytree.Chi2CC[i]>0.0872 or mytree.StatCC[i]<=0 or mytree.NRowsCC[i]==0) ):    continue     

            #print(mytree.pid[i])
            i_lv = ROOT.TLorentzVector()    ## 4-vector of the hadron
            i_lv.SetPxPyPzE(mytree.Px[i],mytree.Py[i],mytree.Pz[i],mytree.Zh[i]*Nu) ## this is the 4-vector of the hadron
            i_part = particle(mytree.pid[i], i_lv, virtual_photon, mytree.ThetaPQ[i] ) ## particle is the class defined previously
            
            if include_truth:
                i_lv_truth = ROOT.TLorentzVector()    ## 4-vector of the hadron
                i_lv_truth.SetPxPyPzE(mytree.mc_Px[i],mytree.mc_Py[i],mytree.mc_Pz[i],mytree.mc_Zh[i]*Nu_truth) ## this is the 4-vector of the hadron
                i_part_truth = particle(mytree.mc_pid[i], i_lv_truth, virtual_photon_truth, mytree.mc_ThetaPQ[i] ) ## particle is the class defined previously
             
            
            
            ## in this 'particles' list there are NO cuts applied (except the pid and obvious ones)
            particles.append(i_part)   ## save that particle in the 'particles' list
            X = (virtual_photon + proton -  i_part.LorentzVector) #unobserved hadronic system
            #print('event:',ievt,'particle i:', i,' with PID:',  i_part.pid, 'and Zh:', i_part.Zh, ', W: ',i_part.W)
            #if i_part.Pt>1.0: #only save triggers if pT>1.0 
            if i_part.Zh > 0.4 or (include_truth and i_part_truth.Zh>0.4): #only save triggers and do correlations if they have z>0.4
            ## HERE WE SAVE THE VARIABLES FOR THE TRIGGER PARTICLE (THE ONE WITH Zh>0.4)
                tupla_trigger['TargType'].append(mytree.TargType)
                tupla_trigger['h1_pid'].append(i_part.pid)
                tupla_trigger['h1_xf'].append(i_part.Xf)
                tupla_trigger['h1_xf_default'].append(-1)
                tupla_trigger['h1_z'].append(i_part.Zh)
                tupla_trigger['h1_cm_pt'].append(i_part.Pt)
                tupla_trigger['h1_rap'].append(i_part.y_star)
                tupla_trigger['ycm'].append(i_part.ycm)
                tupla_trigger['h1_cm_ph'].append(i_part.PhiPQ)
                tupla_trigger['h1_cm_th'].append(i_part.ThetaPQ)
                tupla_trigger['missing_mass'].append(X.M())
                tupla_trigger['Q2'].append(mytree.Q2)
                tupla_trigger['x'].append(mytree.Xb)
                tupla_trigger['nu'].append(mytree.Nu)
                tupla_trigger['W'].append(mytree.W)
                tupla_trigger['h1_ph'].append(mytree.PhiLab[i])
                tupla_trigger['h1_th'].append(mytree.ThetaLab[i])#i_part.LorentzVector.Theta())
                #print 'mytree.Pt[i] ' , mytree.Pt[i], ' check: ' ,i_part.Vector.Perp(virtual_photon_unitvector)
                
                #print('Testing theta PQ', mytree.ThetaPQ[i],  ' '  , 180.0*i_part.ThetaPQ/np.pi)
                #print('Testing phi PQ', mytree.PhiPQ[i],  ' '  , 180.0*i_part.PhiPQ/np.pi)
#,Nphe,deltaZ                
                for j in range(len(mytree.pid)): 
                    if i==j: continue
                    if (abs(mytree.pid[j]) !=211 and mytree.pid[j]!=2212): continue
                    #print('evnt', ievt,' j:', j, ' , lenpid:',len(mytree.pid) )
                    ## aplying the rest of cuts:
                    if ( mytree.FidCheckCutPiPlus[j]==False or abs(mytree.deltaZ[j])>=3.0 or mytree.P[j]<0.2 or mytree.ThetaLab[j]<10 or mytree.ThetaLab[j]>120 ):    continue
                    if ( mytree.pid[j]==-211 and (mytree.ThetaLab[j]>90 or mytree.ThetaLab[j]<25) ):    continue                
                    if ( mytree.pid[j]==-211 and mytree.ThetaLab[j]>40 and mytree.P[j]<0.2  ):    continue                
                    if ( mytree.pid[j]==-211 and mytree.ThetaLab[j]<40 and mytree.P[j]<0.5  ):    continue 
                    if ( mytree.pid[j]==211  and mytree.P[j]>=2.7 and (mytree.Nphe[j]<15 or mytree.Chi2CC[j]>0.0872 or mytree.StatCC[j]<=0 or mytree.NRowsCC[j]==0) ):    continue     
                        
                    #print('inside j loop')
                    j_lv = ROOT.TLorentzVector()    
                    j_lv.SetPxPyPzE(mytree.Px[j],mytree.Py[j],mytree.Pz[j],mytree.Zh[j]*Nu)
                    j_part = particle(mytree.pid[j], j_lv, virtual_photon, mytree.ThetaPQ[j] ) ## particle is the defined class

                    if include_truth:
                        j_lv_truth = ROOT.TLorentzVector()    ## 4-vector of the hadron
                        j_lv_truth.SetPxPyPzE(mytree.mc_Px[j],mytree.mc_Py[j],mytree.mc_Pz[j],mytree.mc_Zh[j]*Nu_truth) ## this is the 4-vector of the hadron
                        j_part_truth = particle(mytree.mc_pid[j], j_lv_truth, virtual_photon_truth, mytree.mc_ThetaPQ[j] ) ## particle is the class defined previously
                        dphi_truth = abs(ROOT.TVector2.Phi_mpi_pi(i_part_truth.PhiPQ-j_part_truth.PhiPQ))  
                        dphi_lab_truth = abs(ROOT.TVector2.Phi_mpi_pi(i_part_truth.PhiLab-j_part_truth.PhiLab))
                        dy_truth = i_part_truth.y-j_part_truth.y
                        deta_truth = dy_truth
                        
                        dihadron_truth = i_part_truth.LorentzVector+j_part_truth.LorentzVector  ## LorentzVector is a method of the 
                                    #particle class, is the '4-vector' of the particle, 3rd argument of the class
                    
                        X_truth = (virtual_photon_truth + proton - dihadron_truth) #unobserved hadronic system
                        X1_truth = (virtual_photon_truth + proton - i_part_truth.LorentzVector)
                        X2_truth = (virtual_photon_truth + proton - j_part_truth.LorentzVector)
                    
                    ## TVector2.Phi_mpi_pi is a built in function of TVector2 class (2D vectors).
                    ## Returns Phi angle in the interval [-pi,pi]. 
                    ## Also, we used the 'abs' to obtain the 0->pi range
                    
                    dphi = abs(ROOT.TVector2.Phi_mpi_pi(i_part.PhiPQ-j_part.PhiPQ))  
                    dphi_lab = abs(ROOT.TVector2.Phi_mpi_pi(i_part.PhiLab-j_part.PhiLab))
                    
                    
                    
                    dy = i_part.y-j_part.y  ## i_part and j_part are object of the class particles 
                                            # and 'y' is a methos, is the rapidity in the lab frame
                    deta = dy
                    ## Di-hadron 4-vector, is the sum P_{di-hadron} = P_{trigger-hadron} + P_{other-hadron}
                    dipion = i_part.LorentzVector+j_part.LorentzVector  ## LorentzVector is a method of the 
                                    #particle class, is the '4-vector' of the particle, 3rd argument of the class
                    
                    X = (virtual_photon + proton - dipion) #unobserved hadronic system
                    X1 = (virtual_photon + proton - i_part.LorentzVector)
                    X2 = (virtual_photon + proton - j_part.LorentzVector)

                    tupla['dphi'].append(dphi)
                    tupla['dphi_lab'].append(dphi_lab)
                    tupla['drap'].append(dy)
                    tupla['h1_z'].append(i_part.Zh)
                    tupla['h2_z'].append(j_part.Zh)
                    tupla['h1_cm_pt'].append(i_part.Pt)
                    tupla['h2_cm_pt'].append(j_part.Pt)
                    tupla['h1_xf'].append(i_part.Xf)
                    tupla['h2_xf'].append(j_part.Xf)
                    tupla['h1_rap'].append(i_part.y_star)
                    tupla['ycm'].append(i_part.ycm)
                    tupla['h2_rap'].append(j_part.y_star)
                    tupla['h1_pid'].append(i_part.pid)
                    tupla['h2_pid'].append(j_part.pid)
                    tupla['h1_cm_ph'].append(i_part.PhiPQ)
                    tupla['h2_cm_ph'].append(j_part.PhiPQ)
                    tupla['h1_cm_th'].append(i_part.ThetaPQ)
                    tupla['h2_cm_th'].append(j_part.ThetaPQ)
                    tupla['pair_mass'].append(dipion.M())
                    tupla['pair_pt'].append( dipion.Vect().Perp(virtual_photon_unitvector))
                    tupla['mx_eh1h2x'].append(X.M())
                    tupla['mx_eh1x'].append(X1.M())
                    tupla['mx_eh2x'].append(X2.M())
                    tupla['t'].append( -(virtual_photon- dipion).M2())
                    tupla['Q2'].append(mytree.Q2)
                    tupla['x'].append(mytree.Xb)
                    tupla['nu'].append(mytree.Nu)
                    tupla['W'].append(mytree.W)
                    tupla['u'].append(-(scattered_e-proton).M2())
                    tupla['h1_ph'].append(mytree.PhiLab[i])
                    tupla['h1_th'].append(mytree.ThetaLab[i])
                    tupla['h2_ph'].append(mytree.PhiLab[j])
                    tupla['h2_th'].append(mytree.ThetaLab[j])
                    
                    if include_truth:
                        tupla['dphi_truth'].append(dphi_truth)
                        tupla['dphi_lab_truth'].append(dphi_lab_truth)
                        tupla['drap_truth'].append(dy_truth)
                        tupla['h1_truth_z'].append(i_part_truth.Zh)
                        tupla['h2_truth_z'].append(j_part_truth.Zh)
                        tupla['h1_truth_cm_pt'].append(i_part_truth.Pt)
                        tupla['h2_truth_cm_pt'].append(j_part_truth.Pt)
                        tupla['h1_truth_xf'].append(i_part_truth.Xf)
                        tupla['h2_truth_xf'].append(j_part_truth.Xf)
                        tupla['h1_truth_rap'].append(i_part_truth.y_star)
                        tupla['ycm_truth'].append(i_part_truth.ycm)
                        tupla['h2_truth_rap'].append(j_part_truth.y_star)
                        tupla['h1_truth_pid'].append(i_part_truth.pid)
                        tupla['h2_truth_pid'].append(j_part_truth.pid)
                        tupla['h1_truth_cm_ph'].append(i_part_truth.PhiPQ)
                        tupla['h2_truth_cm_ph'].append(j_part_truth.PhiPQ)
                        tupla['h1_truth_cm_th'].append(i_part_truth.ThetaPQ)
                        tupla['h2_truth_cm_th'].append(j_part_truth.ThetaPQ)
                        tupla['pair_mass_truth'].append(dihadron_truth.M())
                        tupla['pair_pt_truth'].append( dihadron_truth.Vect().Perp(virtual_photon_unitvector_truth))
                        tupla['mx_eh1h2x_truth'].append(X_truth.M())
                        tupla['mx_eh1x_truth'].append(X1_truth.M())
                        tupla['mx_eh2x_truth'].append(X2_truth.M())
                        tupla['t_truth'].append( -(virtual_photon_truth- dihadron_truth).M2())
                        
                        tupla['Q2_truth'].append(mytree.mc_Q2)
                        tupla['x_truth'].append(mytree.mc_Xb)
                        tupla['nu_truth'].append(mytree.mc_Nu)
                        tupla['W_truth'].append(mytree.mc_W)
                        tupla['u_truth'].append(-(scattered_e_truth-proton).M2())
                        tupla['h1_truth_ph'].append(mytree.mc_PhiLab[i])
                        tupla['h1_truth_th'].append(mytree.mc_ThetaLab[i])
                        tupla['h2_truth_ph'].append(mytree.mc_PhiLab[j])
                        tupla['h2_truth_th'].append(mytree.mc_ThetaLab[j])
                        
                    
                    
         #end loop over secondary loop    
                #print '//////// Entering mixed event correlations with # ', len(ParticlesFromPrevious) , ' paticles in previous event'
                
                ## here we are still under the condition of Zh>0.4
                #print(ievt,i,j)
                #print('')
                for mixparticle in ParticlesFromPrevious: ## ParticlesFromPrevious is a list 
                                                          ## with 'particle' class objects
                    #print('\ninside mixparticle loop\n')
                    #print('i: ',i,'mixparticles pid:',mixparticle.pid,' zh :', mixparticle.Zh , ', W: ', mixparticle.W, ' i_part Zh:', i_part.Zh, 'i_part.W: ',i_part.W)
                    dphi = abs(ROOT.TVector2.Phi_mpi_pi(i_part.PhiPQ-mixparticle.PhiPQ))
                    tupla_mix['dphi_norot'].append(dphi)
                    tupla_mix['h2_cm_ph_norot'].append(mixparticle.PhiPQ)
                    tupla_mix['h2_cm_th_norot'].append(mixparticle.ThetaPQ)

                    mixparticle.redefine(virtual_photon) 
                    #recalculates variables in this' event photon frame (not in the previous one)
                    #dphi = abs(ROOT.TVector2.Phi_mpi_pi(i_part.PhiPQ-mixparticle.PhiPQ))
                    #print 'dphi_pq after redefinition: ', dphi , ' phi_pq ', mixparticle.PhiPQ
                    
                    dipion = i_part.LorentzVector+mixparticle.LorentzVector
                    X  = (virtual_photon + proton - dipion)
                    X1 = (virtual_photon + proton - i_part.LorentzVector)
                    X2 = (virtual_photon + proton - mixparticle.LorentzVector)

                    #recalculate the phi_pq. It has to be with respect to the photon direction
                    
                    dphi = abs(ROOT.TVector2.Phi_mpi_pi(i_part.PhiPQ-mixparticle.PhiPQ))
                    dphi_lab = abs(ROOT.TVector2.Phi_mpi_pi(i_part.PhiLab-mixparticle.PhiLab))

                    dy = i_part.y-mixparticle.y
                    deta = dy#i_part.ThetaPQ-mixparticle.ThetaPQ
                    tupla_mix['dphi'].append(dphi)
                    tupla_mix['dphi_lab'].append(dphi_lab)
                    tupla_mix['drap'].append(dy)
                    tupla_mix['h1_z'].append(i_part.Zh)
                    tupla_mix['h2_z'].append(mixparticle.Zh)
                    tupla_mix['h1_cm_pt'].append(i_part.Pt)
                    tupla_mix['h2_cm_pt'].append(mixparticle.Pt)
                    tupla_mix['h1_xf'].append(i_part.Xf)
                    tupla_mix['h2_xf'].append(mixparticle.Xf)
                    tupla_mix['h1_rap'].append(i_part.y_star)
                    tupla_mix['ycm'].append(i_part.ycm)
                    tupla_mix['h2_rap'].append(mixparticle.y_star)
                    tupla_mix['h1_pid'].append(i_part.pid)
                    tupla_mix['h2_pid'].append(mixparticle.pid)
                    tupla_mix['h1_cm_ph'].append(i_part.PhiPQ)
                    tupla_mix['h2_cm_ph'].append(mixparticle.PhiPQ)
                    tupla_mix['h1_cm_th'].append(i_part.ThetaPQ)
                    tupla_mix['h2_cm_th'].append(mixparticle.ThetaPQ)
                    tupla_mix['pair_mass'].append(dipion.M())
                    tupla_mix['pair_pt'].append( dipion.Vect().Perp(virtual_photon_unitvector))
                    tupla_mix['mx_eh1h2x'].append(X.M())
                    tupla_mix['mx_eh1x'].append(X1.M())
                    tupla_mix['mx_eh2x'].append(X2.M())
                    tupla_mix['t'].append( -(virtual_photon- dipion).M2())
                    tupla_mix['Q2'].append(mytree.Q2)
                    tupla_mix['x'].append(mytree.Xb)
                    tupla_mix['nu'].append(mytree.Nu)
                    tupla_mix['W'].append(mytree.W)
                    tupla_mix['u'].append(-(scattered_e-proton).M2())
                    tupla_mix['h1_ph'].append(i_part.LorentzVector.Phi())
                    tupla_mix['h1_th'].append(mytree.ThetaLab[i])
                    tupla_mix['h2_ph'].append(mixparticle.LorentzVector.Phi())
                    tupla_mix['h2_th'].append(mytree.ThetaLab[j])
                    #for kk  in range (len(ParticlesFromPrevious)):
                        #print('ParticlesFromPrevious, pid:', ParticlesFromPrevious[kk].pid, 'zh: ', ParticlesFromPrevious[kk].Zh, 'W: ',ParticlesFromPrevious[kk].W )
        #print (' Exiting main loop over particles (i loop, not over all entries)')
        ParticlesFromPrevious = particles
        #print ' going for next event'    
        #print ' particles in event', len(particles
        ##end loop over events correlations    
    end = time.time()
    print ('Processed in',  end-start, 'seconds')
    ##printing the 3 tuples to the output file
    df = pd.DataFrame(tupla)
    df_mix= pd.DataFrame(tupla_mix)
    df_trigger = pd.DataFrame(tupla_trigger)
    print ('Number of triggers with z>0.4,  ', df.query('h1_z>0.4').shape[0])
    print ('Number of pairs with z>0.4, '    , df_trigger.query('h1_z>0.4').shape[0]) 
    myfile.Close()
    return df, df_mix, df_trigger

# %%
## here we defined some dictionaries ({})
df = {}
df_mc = {}

# %% [markdown]
# # Data files

# %%
path = '/home/seba/di-hadron/data/fe/'
#path='/home/seba/'

Files = listdir(path) 
#df['Pb'],df['Pb_mix'], df['Pb_trigger'] = [None,None,None]
#df['D_Pb'],df['D_Pb_mix'], df['D_Pb_trigger'] = [None,None,None]
df['Fe'],df['Fe_mix'], df['Fe_trigger'] = [None,None,None]
df['D_Fe'],df['D_Fe_mix'], df['D_Fe_trigger'] = [None,None,None]
#df['C'],df['C_mix'], df['C_trigger'] = [None,None,None]
#df['D_C'],df['D_C_mix'], df['D_C_trigger'] = [None,None,None]
count=0
for name in Files:
    filename = path+name
    print ('done with: ', count, ' files')
    count=count+1
    if( 'pass2.root' not in name): continue ## when the condition is true the 'continue' statement
                                            ## takes me to the next iteration of the loop
    pairs, pairs_mix, trigger = getDataframes(filename,Target=2) ## getDataframes is a function just created
    df['Fe'] = pd.concat([ df['Fe'], pairs])
    df['Fe_mix'] = pd.concat([ df['Fe_mix'], pairs_mix])
    df['Fe_trigger'] = pd.concat([ df['Fe_trigger'], trigger])
    pairs, pairs_mix, trigger = getDataframes(filename,Target=1) ## getDataframes is a function just created
    df['D_Fe'] = pd.concat([ df['D_Fe'], pairs])
    df['D_Fe_mix'] = pd.concat([ df['D_Fe_mix'], pairs_mix])
    df['D_Fe_trigger'] = pd.concat([ df['D_Fe_trigger'], trigger])
    
#    print('Entries in the dataframe so far are ', df['D_Fe'].shape[0])
#    print('Entries in the MIXED dataframe so far are ', df['D_Fe_mix'].shape[0])
#    print('Entries in the trigger dataframe so far are ', df['D_Fe_trigger'].shape[0])
# Out:
# done with:  0  files
# /home/seba/di-hadron/data/fe/N_clas_41339_00.pass2.root  has  8568  entries
# About to loop over  8568  entries
# Processed in 0.7421207427978516 seconds
# Number of triggers with z>0.4,   461
# Number of pairs with z>0.4,  801
# /home/seba/di-hadron/data/fe/N_clas_41339_00.pass2.root  has  8568  entries
# About to loop over  8568  entries
# Processed in 0.6655504703521729 seconds
# Number of triggers with z>0.4,   338
# Number of pairs with z>0.4,  805
# done with:  1  files
# /home/seba/di-hadron/data/fe/N_clas_41349_19.pass2.root  has  8551  entries
# About to loop over  8551  entries
# Processed in 0.7092275619506836 seconds
# Number of triggers with z>0.4,   471
# Number of pairs with z>0.4,  778
# /home/seba/di-hadron/data/fe/N_clas_41349_19.pass2.root  has  8551  entries
# About to loop over  8551  entries
# Processed in 0.6676573753356934 seconds
# Number of triggers with z>0.4,   322
# Number of pairs with z>0.4,  814
# done with:  2  files
# /home/seba/di-hadron/data/fe/N_clas_41359_02.pass2.root  has  8516  entries
# About to loop over  8516  entries
# Processed in 0.6976723670959473 seconds
# Number of triggers with z>0.4,   461
# Number of pairs with z>0.4,  807
# /home/seba/di-hadron/data/fe/N_clas_41359_02.pass2.root  has  8516  entries
# About to loop over  8516  entries
# Processed in 0.6433777809143066 seconds
# Number of triggers with z>0.4,   320
# Number of pairs with z>0.4,  822
# done with:  3  files
# /home/seba/di-hadron/data/fe/N_clas_41459_16.pass2.root  has  8694  entries
# About to loop over  8694  entries
# Processed in 0.6980631351470947 seconds
# Number of triggers with z>0.4,   470
# Number of pairs with z>0.4,  823
# /home/seba/di-hadron/data/fe/N_clas_41459_16.pass2.root  has  8694  entries
# About to loop over  8694  entries
# Processed in 0.6566801071166992 seconds
# Number of triggers with z>0.4,   332
# Number of pairs with z>0.4,  819
# done with:  4  files
# /home/seba/di-hadron/data/fe/N_clas_41166_07.pass2.root  has  11769  entries
# About to loop over  11769  entries
# Processed in 0.9691457748413086 seconds
# Number of triggers with z>0.4,   645
# Number of pairs with z>0.4,  1103
# /home/seba/di-hadron/data/fe/N_clas_41166_07.pass2.root  has  11769  entries
# About to loop over  11769  entries
# Processed in 0.9467556476593018 seconds
# Number of triggers with z>0.4,   482
# Number of pairs with z>0.4,  1212
# done with:  5  files
# /home/seba/di-hadron/data/fe/N_clas_41364_16.pass2.root  has  8538  entries
# About to loop over  8538  entries
# Processed in 0.6864664554595947 seconds
# Number of triggers with z>0.4,   430
# Number of pairs with z>0.4,  749
# /home/seba/di-hadron/data/fe/N_clas_41364_16.pass2.root  has  8538  entries
# About to loop over  8538  entries
# Processed in 0.6591305732727051 seconds
# Number of triggers with z>0.4,   340
# Number of pairs with z>0.4,  843
# done with:  6  files
# /home/seba/di-hadron/data/fe/N_clas_41499_06.pass2.root  has  8971  entries
# About to loop over  8971  entries
# Processed in 0.7546389102935791 seconds
# Number of triggers with z>0.4,   499
# Number of pairs with z>0.4,  865
# /home/seba/di-hadron/data/fe/N_clas_41499_06.pass2.root  has  8971  entries
# About to loop over  8971  entries

# %%
## this is equivalent to: D_Fe->Draw("h1_ph>>h(100,0,1)"), ok!
plt.hist(df['D_Fe']['h1_ph'],bins=100,range=(0,1.0))
df['D_Fe'].shape[0]  ## shape[0] return the number of rows of the array (number electrons)

# %%
#df['D_C'].query('h2_z>0.2').hist(figsize=(20,20),bins=100,column=['dphi_lab','dphi','h1_ph','h2_ph','h1_cm_ph','h2_cm_ph'])
#plt.savefig('plot_test.png', bbox_inches='tight')
#plt.show()

# %%
df['D_Pb_mix'].query('h2_z>0.2').hist(figsize=(20,20),bins=100,column=['h1_cm_pt','dphi_lab','dphi','h1_ph','h2_ph','h1_cm_ph','h2_cm_ph','h2_pid'])
plt.savefig('plot_test2.png', bbox_inches='tight')
plt.show()

# %%
import root_pandas
from root_pandas import read_root
from root_pandas import to_root

# %%
for target in ['Fe']:
    to_root(df['%s'%target],'Pairs_%s.root'%target, key='%s'%target)
    to_root(df['%s_mix'%target],'Pairs_%s.root'%target, key='%s_mix'%target,mode='a')
    to_root(df['%s_trigger'%target],'Pairs_%s.root'%target, key='%s_trigger'%target, mode='a')
    to_root(df['D_%s'%target],'Pairs_%s.root'%target, key='D_%s'%target,mode='a')
    to_root(df['D_%s_mix'%target],'Pairs_%s.root'%target, key='D_%s_mix'%target,mode='a')
    to_root(df['D_%s_trigger'%target],'Pairs_%s.root'%target, key='D_%s_trigger'%target, mode='a')

# %% [markdown]
# # Simulations

# %%
maxCount = None
for target in 'C', 'Fe','Pb', 'D2':  #Pb already done
    path = f'/home/sebouh/di-hadron/simul/{target}/'
    #path = '/home/seba/di-hadron/simul/'
    Files = listdir(path) 
    df_mc[target],df_mc[target+'_mix'], df_mc[target+'_trigger'] = [None,None,None]
    count =0
    for name in Files:
        print('done with: ', count, ' files')
        if maxCount is not None and count > maxCount:
            break
        count=count+1
        if( '.root' not in name): continue

        filename = path+name
        print(filename)
        pairs, pairs_mix, trigger = getDataframes(filename,tree_name='ntuple_sim',Target=1,isMC=True, include_truth=True)
        df_mc[target] = pd.concat([ df_mc[target], pairs])
        df_mc[target+'_mix'] = pd.concat([ df_mc[target+'_mix'], pairs_mix])
        df_mc[target+'_trigger'] = pd.concat([ df_mc[target+'_trigger'], trigger])

        print('Entries in the dataframe so far are ', df_mc[target].shape[0])
        print('Entries in the MIXED dataframe so far are ', df_mc[target+'_mix'].shape[0])
        print('Entries in the trigger dataframe so far are ', df_mc[target+'_trigger'].shape[0])
# Out:
# done with:  0  files
# /home/seba/di-hadron/simul/C/C9.root
# /home/seba/di-hadron/simul/C/C9.root  has  10000000  entries
# About to loop over  10000000  entries
# <ipython-input-5-1a0a23e842e9>:14: RuntimeWarning: invalid value encountered in arccos
#   self.PhiPQ = sign*np.arccos(part1.Dot(part2))
# Processed in 735.2602589130402 seconds
# Number of triggers with z>0.4,   242608
# Number of pairs with z>0.4,  686540
# Entries in the dataframe so far are  245922
# Entries in the MIXED dataframe so far are  436369
# Entries in the trigger dataframe so far are  694805
# done with:  1  files
# /home/seba/di-hadron/simul/C/C8.root
# /home/seba/di-hadron/simul/C/C8.root  has  9980000  entries
# About to loop over  9980000  entries
# Processed in 740.9925920963287 seconds
# Number of triggers with z>0.4,   242791
# Number of pairs with z>0.4,  686559
# Entries in the dataframe so far are  492012
# Entries in the MIXED dataframe so far are  873074
# Entries in the trigger dataframe so far are  1389496
# done with:  2  files
# /home/seba/di-hadron/simul/C/C1.root
# /home/seba/di-hadron/simul/C/C1.root  has  9940000  entries
# About to loop over  9940000  entries
# Processed in 734.4319269657135 seconds
# Number of triggers with z>0.4,   240679
# Number of pairs with z>0.4,  680623
# Entries in the dataframe so far are  735791
# Entries in the MIXED dataframe so far are  1306281
# Entries in the trigger dataframe so far are  2078050
# done with:  3  files
# /home/seba/di-hadron/simul/C/C2.root
# /home/seba/di-hadron/simul/C/C2.root  has  9820000  entries
# About to loop over  9820000  entries
# Processed in 727.368974685669 seconds
# Number of triggers with z>0.4,   238394
# Number of pairs with z>0.4,  673484
# Entries in the dataframe so far are  977371
# Entries in the MIXED dataframe so far are  1734434
# Entries in the trigger dataframe so far are  2759555
# done with:  4  files
# /home/seba/di-hadron/simul/C/C4.root
# /home/seba/di-hadron/simul/C/C4.root  has  9980000  entries
# About to loop over  9980000  entries
# Processed in 727.1631534099579 seconds
# Number of triggers with z>0.4,   241549
# Number of pairs with z>0.4,  683831
# Entries in the dataframe so far are  1222161
# Entries in the MIXED dataframe so far are  2170000
# Entries in the trigger dataframe so far are  3451561
# done with:  5  files
# /home/seba/di-hadron/simul/C/C7.root
# /home/seba/di-hadron/simul/C/C7.root  has  10000000  entries
# About to loop over  10000000  entries
# Processed in 734.6022717952728 seconds
# Number of triggers with z>0.4,   242368
# Number of pairs with z>0.4,  685491
# Entries in the dataframe so far are  1467827
# Entries in the MIXED dataframe so far are  2605863
# Entries in the trigger dataframe so far are  4145288
# done with:  6  files
# /home/seba/di-hadron/simul/C/C3.root
# /home/seba/di-hadron/simul/C/C3.root  has  9380000  entries
# About to loop over  9380000  entries
# Processed in 684.9569594860077 seconds
# Number of triggers with z>0.4,   228477
# Number of pairs with z>0.4,  643365
# Entries in the dataframe so far are  1699369
# Entries in the MIXED dataframe so far are  3015238
# Entries in the trigger dataframe so far are  4796338
# done with:  7  files
# /home/seba/di-hadron/simul/C/C5.root
# /home/seba/di-hadron/simul/C/C5.root  has  9740000  entries
# About to loop over  9740000  entries
# Processed in 723.4544105529785 seconds
# Number of triggers with z>0.4,   235882
# Number of pairs with z>0.4,  667931
# Entries in the dataframe so far are  1938492
# Entries in the MIXED dataframe so far are  3441206
# Entries in the trigger dataframe so far are  5472421
# done with:  8  files
# /home/seba/di-hadron/simul/C/C6.root
# /home/seba/di-hadron/simul/C/C6.root  has  9940000  entries
# About to loop over  9940000  entries
# Processed in 732.2169876098633 seconds
# Number of triggers with z>0.4,   241136
# Number of pairs with z>0.4,  681781
# Entries in the dataframe so far are  2182954
# Entries in the MIXED dataframe so far are  3874218
# Entries in the trigger dataframe so far are  6162447
# done with:  0  files
# /home/seba/di-hadron/simul/Fe/Fe2.root
# /home/seba/di-hadron/simul/Fe/Fe2.root  has  9840000  entries
# About to loop over  9840000  entries
# Processed in 715.5429790019989 seconds
# Number of triggers with z>0.4,   233698
# Number of pairs with z>0.4,  663126
# Entries in the dataframe so far are  237123
# Entries in the MIXED dataframe so far are  421926
# Entries in the trigger dataframe so far are  671774
# done with:  1  files
# /home/seba/di-hadron/simul/Fe/Fe8.root
# /home/seba/di-hadron/simul/Fe/Fe8.root  has  7720000  entries
# About to loop over  7720000  entries
# Processed in 562.2367329597473 seconds
# Number of triggers with z>0.4,   184421
# Number of pairs with z>0.4,  522043
# Entries in the dataframe so far are  424111
# Entries in the MIXED dataframe so far are  754018
# Entries in the trigger dataframe so far are  1200570
# done with:  2  files
# /home/seba/di-hadron/simul/Fe/Fe9.root
# /home/seba/di-hadron/simul/Fe/Fe9.root  has  9969490  entries
# About to loop over  9969490  entries
# Processed in 729.9579887390137 seconds
# Number of triggers with z>0.4,   237685
# Number of pairs with z>0.4,  673239
# Entries in the dataframe so far are  665223
# Entries in the MIXED dataframe so far are  1181400
# Entries in the trigger dataframe so far are  1882486
# done with:  3  files
# /home/seba/di-hadron/simul/Fe/Fe5.root
# /home/seba/di-hadron/simul/Fe/Fe5.root  has  9600000  entries
# About to loop over  9600000  entries
# Processed in 691.9511206150055 seconds
# Number of triggers with z>0.4,   227537
# Number of pairs with z>0.4,  646397
# Entries in the dataframe so far are  896019
# Entries in the MIXED dataframe so far are  1592494
# Entries in the trigger dataframe so far are  2537171
# done with:  4  files
# /home/seba/di-hadron/simul/Fe/Fe4.root
# /home/seba/di-hadron/simul/Fe/Fe4.root  has  8840000  entries
# About to loop over  8840000  entries
# Processed in 630.0674970149994 seconds
# Number of triggers with z>0.4,   208463
# Number of pairs with z>0.4,  594922
# Entries in the dataframe so far are  1107513
# Entries in the MIXED dataframe so far are  1969568
# Entries in the trigger dataframe so far are  3139932
# done with:  5  files
# /home/seba/di-hadron/simul/Fe/Fe7.root
# /home/seba/di-hadron/simul/Fe/Fe7.root  has  10000000  entries
# About to loop over  10000000  entries
# Processed in 720.3342156410217 seconds
# Number of triggers with z>0.4,   237948
# Number of pairs with z>0.4,  674367
# Entries in the dataframe so far are  1348922
# Entries in the MIXED dataframe so far are  2397573
# Entries in the trigger dataframe so far are  3823221
# done with:  6  files
# /home/seba/di-hadron/simul/Fe/Fe6.root
# /home/seba/di-hadron/simul/Fe/Fe6.root  has  8300000  entries
# About to loop over  8300000  entries
# Processed in 605.5719621181488 seconds
# Number of triggers with z>0.4,   198008
# Number of pairs with z>0.4,  560049
# Entries in the dataframe so far are  1549981
# Entries in the MIXED dataframe so far are  2752965
# Entries in the trigger dataframe so far are  4390766
# done with:  7  files
# /home/seba/di-hadron/simul/Fe/Fe1.root
# /home/seba/di-hadron/simul/Fe/Fe1.root  has  9860000  entries
# About to loop over  9860000  entries
# Processed in 718.3318951129913 seconds
# Number of triggers with z>0.4,   233590
# Number of pairs with z>0.4,  662537
# Entries in the dataframe so far are  1786865
# Entries in the MIXED dataframe so far are  3173708
# Entries in the trigger dataframe so far are  5061738
# done with:  8  files
# /home/seba/di-hadron/simul/Fe/Fe3.root
# /home/seba/di-hadron/simul/Fe/Fe3.root  has  9780000  entries
# About to loop over  9780000  entries
# Processed in 713.5561046600342 seconds
# Number of triggers with z>0.4,   232234
# Number of pairs with z>0.4,  658482
# Entries in the dataframe so far are  2022349
# Entries in the MIXED dataframe so far are  3592464
# Entries in the trigger dataframe so far are  5728761
# done with:  0  files
# /home/seba/di-hadron/simul/Pb/Pb4.root
# /home/seba/di-hadron/simul/Pb/Pb4.root  has  9320000  entries
# About to loop over  9320000  entries
# Processed in 667.7883784770966 seconds
# Number of triggers with z>0.4,   219816
# Number of pairs with z>0.4,  624724
# Entries in the dataframe so far are  222956
# Entries in the MIXED dataframe so far are  396950
# Entries in the trigger dataframe so far are  632827
# done with:  1  files
# /home/seba/di-hadron/simul/Pb/Pb9.root
# /home/seba/di-hadron/simul/Pb/Pb9.root  has  9940000  entries
# About to loop over  9940000  entries
# Processed in 707.6027529239655 seconds
# Number of triggers with z>0.4,   235133
# Number of pairs with z>0.4,  667420
# Entries in the dataframe so far are  461478
# Entries in the MIXED dataframe so far are  820345
# Entries in the trigger dataframe so far are  1308886
# done with:  2  files
# /home/seba/di-hadron/simul/Pb/Pb2.root
# /home/seba/di-hadron/simul/Pb/Pb2.root  has  9940000  entries
# About to loop over  9940000  entries
# Processed in 719.4105188846588 seconds
# Number of triggers with z>0.4,   235266
# Number of pairs with z>0.4,  667899
# Entries in the dataframe so far are  700231
# Entries in the MIXED dataframe so far are  1244516
# Entries in the trigger dataframe so far are  1985584
# done with:  3  files
# /home/seba/di-hadron/simul/Pb/Pb6.root
# /home/seba/di-hadron/simul/Pb/Pb6.root  has  9980000  entries
# About to loop over  9980000  entries
# Processed in 714.2307090759277 seconds
# Number of triggers with z>0.4,   237531
# Number of pairs with z>0.4,  671505
# Entries in the dataframe so far are  941185
# Entries in the MIXED dataframe so far are  1670956
# Entries in the trigger dataframe so far are  2665764
# done with:  4  files
# /home/seba/di-hadron/simul/Pb/Pb7.root
# /home/seba/di-hadron/simul/Pb/Pb7.root  has  10000000  entries
# About to loop over  10000000  entries
# Processed in 726.4903485774994 seconds
# Number of triggers with z>0.4,   236110
# Number of pairs with z>0.4,  671685
# Entries in the dataframe so far are  1180683
# Entries in the MIXED dataframe so far are  2096679
# Entries in the trigger dataframe so far are  3346179
# done with:  5  files
# /home/seba/di-hadron/simul/Pb/Pb8.root
# /home/seba/di-hadron/simul/Pb/Pb8.root  has  10000000  entries
# About to loop over  10000000  entries
# Processed in 723.3615016937256 seconds
# Number of triggers with z>0.4,   237327
# Number of pairs with z>0.4,  673710
# Entries in the dataframe so far are  1421518
# Entries in the MIXED dataframe so far are  2525336
# Entries in the trigger dataframe so far are  4028672
# done with:  6  files
# /home/seba/di-hadron/simul/Pb/Pb5.root
# /home/seba/di-hadron/simul/Pb/Pb5.root  has  9980000  entries
# About to loop over  9980000  entries
# Processed in 729.7660064697266 seconds
# Number of triggers with z>0.4,   236426
# Number of pairs with z>0.4,  670660
# Entries in the dataframe so far are  1661351
# Entries in the MIXED dataframe so far are  2951393
# Entries in the trigger dataframe so far are  4707990
# done with:  7  files
# /home/seba/di-hadron/simul/Pb/Pb3.root
# /home/seba/di-hadron/simul/Pb/Pb3.root  has  9760000  entries
# About to loop over  9760000  entries
# Processed in 714.5758414268494 seconds
# Number of triggers with z>0.4,   231691
# Number of pairs with z>0.4,  655225
# Entries in the dataframe so far are  1896399
# Entries in the MIXED dataframe so far are  3368481
# Entries in the trigger dataframe so far are  5371813
# done with:  8  files
# /home/seba/di-hadron/simul/Pb/Pb1.root
# /home/seba/di-hadron/simul/Pb/Pb1.root  has  9760000  entries
# About to loop over  9760000  entries
# Processed in 708.4641857147217 seconds
# Number of triggers with z>0.4,   230439
# Number of pairs with z>0.4,  654509
# Entries in the dataframe so far are  2130134
# Entries in the MIXED dataframe so far are  3784642
# Entries in the trigger dataframe so far are  6034818
# done with:  0  files
# /home/seba/di-hadron/simul/D2/D2_6.root
# /home/seba/di-hadron/simul/D2/D2_6.root  has  10000000  entries
# About to loop over  10000000  entries
# Processed in 732.1670243740082 seconds
# Number of triggers with z>0.4,   248491
# Number of pairs with z>0.4,  700864
# Entries in the dataframe so far are  251713
# Entries in the MIXED dataframe so far are  448235
# Entries in the trigger dataframe so far are  708856
# done with:  1  files
# /home/seba/di-hadron/simul/D2/D2_9.root
# /home/seba/di-hadron/simul/D2/D2_9.root  has  9320000  entries
# About to loop over  9320000  entries
# Processed in 694.3624770641327 seconds
# Number of triggers with z>0.4,   231078
# Number of pairs with z>0.4,  653154
# Entries in the dataframe so far are  485650
# Entries in the MIXED dataframe so far are  865783
# Entries in the trigger dataframe so far are  1369312
# done with:  2  files
# /home/seba/di-hadron/simul/D2/D2_3.root
# /home/seba/di-hadron/simul/D2/D2_3.root  has  9860000  entries
# About to loop over  9860000  entries
# Processed in 720.989718914032 seconds
# Number of triggers with z>0.4,   244740
# Number of pairs with z>0.4,  688273
# Entries in the dataframe so far are  733498
# Entries in the MIXED dataframe so far are  1307466
# Entries in the trigger dataframe so far are  2065302
# done with:  3  files
# /home/seba/di-hadron/simul/D2/D2_8.root
# /home/seba/di-hadron/simul/D2/D2_8.root  has  10000000  entries
# About to loop over  10000000  entries
# Processed in 744.8963103294373 seconds
# Number of triggers with z>0.4,   247790
# Number of pairs with z>0.4,  701866
# Entries in the dataframe so far are  984558
# Entries in the MIXED dataframe so far are  1757235
# Entries in the trigger dataframe so far are  2775145
# done with:  4  files
# /home/seba/di-hadron/simul/D2/D2_4.root
# /home/seba/di-hadron/simul/D2/D2_4.root  has  9960000  entries
# About to loop over  9960000  entries
# Processed in 740.2643189430237 seconds
# Number of triggers with z>0.4,   244963
# Number of pairs with z>0.4,  694547
# Entries in the dataframe so far are  1232792
# Entries in the MIXED dataframe so far are  2201889
# Entries in the trigger dataframe so far are  3477591
# done with:  5  files
# /home/seba/di-hadron/simul/D2/D2_5.root
# /home/seba/di-hadron/simul/D2/D2_5.root  has  9960000  entries
# About to loop over  9960000  entries
# Processed in 737.2513511180878 seconds
# Number of triggers with z>0.4,   246168
# Number of pairs with z>0.4,  695261
# Entries in the dataframe so far are  1482112
# Entries in the MIXED dataframe so far are  2647165
# Entries in the trigger dataframe so far are  4180666
# done with:  6  files
# /home/seba/di-hadron/simul/D2/D2_2.root
# /home/seba/di-hadron/simul/D2/D2_2.root  has  9880000  entries
# About to loop over  9880000  entries
# Processed in 725.3832626342773 seconds
# Number of triggers with z>0.4,   244071
# Number of pairs with z>0.4,  690090
# Entries in the dataframe so far are  1729238
# Entries in the MIXED dataframe so far are  3088761
# Entries in the trigger dataframe so far are  4878328
# done with:  7  files
# /home/seba/di-hadron/simul/D2/D2_7.root
# /home/seba/di-hadron/simul/D2/D2_7.root  has  9980000  entries
# About to loop over  9980000  entries
# Processed in 746.7684125900269 seconds
# Number of triggers with z>0.4,   246649
# Number of pairs with z>0.4,  699059
# Entries in the dataframe so far are  1979104
# Entries in the MIXED dataframe so far are  3536709
# Entries in the trigger dataframe so far are  5585332
# done with:  8  files
# /home/seba/di-hadron/simul/D2/D2_1.root
# /home/seba/di-hadron/simul/D2/D2_1.root  has  9840000  entries
# About to loop over  9840000  entries
# Processed in 734.8792247772217 seconds
# Number of triggers with z>0.4,   242479
# Number of pairs with z>0.4,  685960
# Entries in the dataframe so far are  2224737
# Entries in the MIXED dataframe so far are  3975279
# Entries in the trigger dataframe so far are  6278767
# TFile: name=/home/seba/di-hadron/simul/C/C9.root, title=, option=READ
# TFile: name=/home/seba/di-hadron/simul/C/C8.root, title=, option=READ
# TFile: name=/home/seba/di-hadron/simul/C/C1.root, title=, option=READ
# TFile: name=/home/seba/di-hadron/simul/C/C2.root, title=, option=READ
# TFile: name=/home/seba/di-hadron/simul/C/C4.root, title=, option=READ
# TFile: name=/home/seba/di-hadron/simul/C/C7.root, title=, option=READ
# TFile: name=/home/seba/di-hadron/simul/C/C3.root, title=, option=READ
# TFile: name=/home/seba/di-hadron/simul/C/C5.root, title=, option=READ
# TFile: name=/home/seba/di-hadron/simul/C/C6.root, title=, option=READ
# TFile: name=/home/seba/di-hadron/simul/Fe/Fe2.root, title=, option=READ
# TFile: name=/home/seba/di-hadron/simul/Fe/Fe8.root, title=, option=READ
# TFile: name=/home/seba/di-hadron/simul/Fe/Fe9.root, title=, option=READ
# TFile: name=/home/seba/di-hadron/simul/Fe/Fe5.root, title=, option=READ
# TFile: name=/home/seba/di-hadron/simul/Fe/Fe4.root, title=, option=READ
# TFile: name=/home/seba/di-hadron/simul/Fe/Fe7.root, title=, option=READ
# TFile: name=/home/seba/di-hadron/simul/Fe/Fe6.root, title=, option=READ
# TFile: name=/home/seba/di-hadron/simul/Fe/Fe1.root, title=, option=READ
# TFile: name=/home/seba/di-hadron/simul/Fe/Fe3.root, title=, option=READ
# TFile: name=/home/seba/di-hadron/simul/Pb/Pb4.root, title=, option=READ
# TFile: name=/home/seba/di-hadron/simul/Pb/Pb9.root, title=, option=READ
# TFile: name=/home/seba/di-hadron/simul/Pb/Pb2.root, title=, option=READ
# TFile: name=/home/seba/di-hadron/simul/Pb/Pb6.root, title=, option=READ
# TFile: name=/home/seba/di-hadron/simul/Pb/Pb7.root, title=, option=READ
# TFile: name=/home/seba/di-hadron/simul/Pb/Pb8.root, title=, option=READ
# TFile: name=/home/seba/di-hadron/simul/Pb/Pb5.root, title=, option=READ
# TFile: name=/home/seba/di-hadron/simul/Pb/Pb3.root, title=, option=READ
# TFile: name=/home/seba/di-hadron/simul/Pb/Pb1.root, title=, option=READ
# TFile: name=/home/seba/di-hadron/simul/D2/D2_6.root, title=, option=READ
# TFile: name=/home/seba/di-hadron/simul/D2/D2_9.root, title=, option=READ
# TFile: name=/home/seba/di-hadron/simul/D2/D2_3.root, title=, option=READ
# TFile: name=/home/seba/di-hadron/simul/D2/D2_8.root, title=, option=READ
# TFile: name=/home/seba/di-hadron/simul/D2/D2_4.root, title=, option=READ
# TFile: name=/home/seba/di-hadron/simul/D2/D2_5.root, title=, option=READ
# TFile: name=/home/seba/di-hadron/simul/D2/D2_2.root, title=, option=READ
# TFile: name=/home/seba/di-hadron/simul/D2/D2_7.root, title=, option=READ
# TFile: name=/home/seba/di-hadron/simul/D2/D2_1.root, title=, option=READ
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN
# Error in <TROOT::TVector2::Phi_mpi_pi>: function called with NaN

# %%
df_mc['D'].hist(figsize=(20,20),bins=100)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-095c993a018d> in <module>
# ----> 1 df_mc['D'].hist(figsize=(20,20),bins=100)
#       2 plt.show()
#
# NameError: name 'df_mc' is not defined

# %% [markdown]
# # Saving the MC file

# %%
import root_pandas
# Out:
# /home/sebouh/.local/lib/python3.8/site-packages/uproot3/__init__.py:127: FutureWarning: Consider switching from 'uproot3' to 'uproot', since the new interface became the default in 2020.
#
#     pip install -U uproot
#
# In Python:
#
#     >>> import uproot
#     >>> with uproot.open(...) as file:
#     ...
#
#   warnings.warn(
# /home/sebouh/.local/lib/python3.8/site-packages/awkward0/__init__.py:12: FutureWarning: Consider switching from 'awkward0' to 'awkward', since the new interface became the default in 2020.
#
#     pip install -U awkward
#
# In Python:
#
#     >>> import awkward as ak
#     >>> new_style_array = ak.from_awkward0(old_style_array)
#     >>> old_style_array = ak.to_awkward0(new_style_array)
#
#   warnings.warn(

# %%
print(df_mc['D2'].columns)
# Out:
# Index(['dphi', 'dphi_lab', 'drap', 'h1_z', 'h2_z', 'h1_cm_pt', 'h2_cm_pt',
#        'h1_xf', 'h2_xf', 'h1_rap', 'ycm', 'h2_rap', 'h1_pid', 'h2_pid',
#        'h1_cm_ph', 'h2_cm_ph', 'h1_cm_th', 'h2_cm_th', 'pair_mass', 'pair_pt',
#        'mx_eh1h2x', 'mx_eh1x', 'mx_eh2x', 't', 'Q2', 'nu', 'W', 'x', 'u',
#        'h1_ph', 'h1_th', 'h2_ph', 'h2_th'],
#       dtype='object')

# %%
df_mc['D'] = df_mc['D2']
df_mc['D_mix'] = df_mc['D2_mix']
df_mc['D_trigger'] = df_mc['D2_trigger']
for target in ['Pb', 'C', 'D', 'Fe']:
    root_pandas.to_root_multi('MC_Pairs_%s.root'%target,
                              {'%s'%target: df_mc['%s'%target],
                               '%s_mix'%target: df_mc['%s_mix'%target],
                               '%s_trigger'%target: df_mc['%s_trigger'%target]})

# %%
for kk in range(5):
    print('inside the loop',kk)
print('outside the loop',kk)

# %%
    for ievt  in range(mytree.GetEntries()):
        mytree.GetEntry(ievt)   
        particles = []  ## this is how you define a list in python, this is created for each event
        for i in range(len(mytree.pid)):
            i_part = particle(mytree.pid[i], i_lv, virtual_photon, mytree.ThetaPQ[i], mytree.Nphe[i], mytree.deltaZ[i], mytree.FidCheckCutPiPlus[i])     
            particles.append(i_part)
            if i_part.Zh > 0.4: #only save triggers and do correlations if they have z>0.4
                #tupla_trigger['h1_th'].append(mytree.ThetaLab[i])#i_part.LorentzVector.Theta())
                #for j in range(len(mytree.pid)): 
                #    if i==j: continue
                #    tupla['dphi'].append(dphi)
                #print(ievt,i,j)
                for mixparticle in ParticlesFromPrevious:
                    print('inside mixparticle loop')
                    #print(i,mixparticle, ParticlesFromPrevious)
                    dphi = abs(ROOT.TVector2.Phi_mpi_pi(i_part.PhiPQ-mixparticle.PhiPQ))
                    tupla_mix['dphi_norot'].append(dphi)

                    mixparticle.redefine(virtual_photon) #recalculates variables in this' event photon frame (not in the previous one)
                    tupla_mix['h2_th'].append(mytree.ThetaLab[j])
        #print (' Exiting main loop over particles (i loop, not over all entries)')
        ParticlesFromPrevious = particles
        #print ' going for next event'    
        #print ' particles in event', len(particles
        ##end loop over events correlations    
    end = time.time()
    return df, df_mix, df_trigger

# %%
print(df_mc['D'].columns)
# Out:
# Index(['dphi', 'dphi_lab', 'drap', 'h1_z', 'h2_z', 'h1_cm_pt', 'h2_cm_pt',
#        'h1_xf', 'h2_xf', 'h1_rap', 'ycm', 'h2_rap', 'h1_pid', 'h2_pid',
#        'h1_cm_ph', 'h2_cm_ph', 'h1_cm_th', 'h2_cm_th', 'pair_mass', 'pair_pt',
#        'mx_eh1h2x', 'mx_eh1x', 'mx_eh2x', 't', 'Q2', 'nu', 'W', 'x', 'u',
#        'h1_ph', 'h1_th', 'h2_ph', 'h2_th', 'dphi_truth', 'dphi_lab_truth',
#        'drap_truth', 'h1_truth_z', 'h2_truth_z', 'h1_truth_cm_pt',
#        'h2_truth_cm_pt', 'h1_truth_xf', 'h2_truth_xf', 'h1_truth_rap',
#        'ycm_truth', 'h2_truth_rap', 'h1_truth_pid', 'h2_truth_pid',
#        'h1_truth_cm_ph', 'h2_truth_cm_ph', 'h1_truth_cm_th', 'h2_truth_cm_th',
#        'pair_mass_truth', 'pair_pt_truth', 'mx_eh1h2x_truth', 'mx_eh1x_truth',
#        'mx_eh2x_truth', 't_truth', 'Q2_truth', 'nu_truth', 'W_truth',
#        'x_truth', 'u_truth', 'h1_truth_ph', 'h1_truth_th', 'h2_truth_ph',
#        'h2_truth_th'],
#       dtype='object')
