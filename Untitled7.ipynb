# %%
import pickle
with open('syst_from_misid.pkl', 'rb') as f:
    syst_from_misid = pickle.load(f)
with open('/home/seba/2d_Correlations/syst_from_misid.pkl', 'rb') as f:
    syst_from_misid_original = pickle.load(f)

# %%
syst_from_misid
# Out:
# {'all': [array([0.07879656, 0.03271538, 0.00684932, 0.00549218, 0.00549954,
#          0.00709677, 0.00925622, 0.03201629])],
#  'dY': [array([0.07142857, 0.        , 0.        , 0.        , 0.        ,
#          0.00810537, 0.00820345, 0.0206859 ]),
#   array([0.14600551, 0.06066946, 0.00983146, 0.00522778, 0.00617284,
#          0.00513779, 0.00880799, 0.02924735]),
#   array([0.00315457, 0.00243309, 0.00378788, 0.00761421, 0.00664207,
#          0.01008827, 0.01022147, 0.04424614])],
#  'pT1': [array([0.05698006, 0.03296703, 0.01041667, 0.00587544, 0.00854093,
#          0.00899101, 0.01454177, 0.05610473]),
#   array([0.10121457, 0.04204204, 0.00212314, 0.00837321, 0.00426309,
#          0.00571633, 0.00722233, 0.03050471]),
#   array([0.10752688, 0.00847458, 0.00793651, 0.00158228, 0.00338409,
#          0.00785546, 0.00711332, 0.02322959])],
#  'pT2': [array([0.08173077, 0.02862595, 0.00562588, 0.01003344, 0.00752941,
#          0.00814725, 0.01554889, 0.04160541]),
# ...

# %%
syst_from_misid_original
# Out:
# {'all': [array([0.08452722, 0.03380589, 0.01065449, 0.00887199, 0.00756187,
#          0.00851613, 0.0107661 , 0.03349681])],
#  'dY': [array([0.07142857, 0.        , 0.        , 0.        , 0.        ,
#          0.01156812, 0.01090343, 0.02039429]),
#   array([0.34375   , 0.15131579, 0.02766798, 0.00711744, 0.00992063,
#          0.0087146 , 0.0090276 , 0.0267398 ]),
#   array([0.05106383, 0.02147239, 0.0043573 , 0.01029601, 0.00773558,
#          0.0053148 , 0.01250539, 0.03410662]),
#   array([0.0041841 , 0.00319489, 0.01017812, 0.01358234, 0.00695134,
#          0.01172529, 0.00878049, 0.03866862])],
#  'pT1': [array([0.05982906, 0.03296703, 0.01388889, 0.00940071, 0.0113879 ,
#          0.01048951, 0.01521813, 0.05877638]),
#   array([0.11336032, 0.04204204, 0.00424628, 0.01196172, 0.00487211,
#          0.00714541, 0.00936951, 0.03244592]),
#   array([0.10752688, 0.01694915, 0.01587302, 0.00316456, 0.00676819,
#          0.00903378, 0.00843672, 0.02413171])],
# ...

# %%
with open('misid_K_rate.pkl', 'rb') as f:
    K = pickle.load(f)
with open('misid_p_rate.pkl', 'rb') as f:
    p = pickle.load(f)

# %%
K
# Out:
# {'all': [array([0.00286533, 0.00218103, 0.00228311, 0.00422476, 0.00320807,
#          0.0036129 , 0.00538305, 0.01133525])],
#  'dY': [array([0.        , 0.        , 0.        , 0.        , 0.        ,
#          0.00506586, 0.00615258, 0.01415351]),
#   array([0.00275482, 0.00209205, 0.00140449, 0.00448096, 0.00411523,
#          0.00303596, 0.00634175, 0.01352994]),
#   array([0.00315457, 0.00243309, 0.00378788, 0.00507614, 0.00295203,
#          0.0037831 , 0.00292042, 0.0046477 ])],
#  'pT1': [array([0.002849  , 0.0021978 , 0.00347222, 0.00352526, 0.00569395,
#          0.0024975 , 0.00304363, 0.00374032]),
#   array([0.00404858, 0.003003  , 0.        , 0.00717703, 0.00182704,
#          0.0035727 , 0.00448956, 0.00665557]),
#   array([0.        , 0.        , 0.00396825, 0.00158228, 0.00169205,
#          0.00471328, 0.00545906, 0.01511051])],
#  'pT2': [array([0.00240385, 0.0019084 , 0.00140647, 0.00752508, 0.00517647,
#          0.00452625, 0.01311353, 0.0311673 ]),
# ...

# %%
p
# Out:
# {'all': [array([0.07449857, 0.03053435, 0.00456621, 0.00084495, 0.00229148,
#          0.00309677, 0.00380752, 0.02063477])],
#  'dY': [array([0.07142857, 0.        , 0.        , 0.        , 0.        ,
#          0.00303951, 0.00164069, 0.00653239]),
#   array([0.14049587, 0.05857741, 0.00842697, 0.        , 0.00205761,
#          0.00186829, 0.00246624, 0.01563639]),
#   array([0.        , 0.        , 0.        , 0.00253807, 0.00369004,
#          0.00546448, 0.00730105, 0.03959844])],
#  'pT1': [array([0.05128205, 0.03076923, 0.00694444, 0.00117509, 0.00284698,
#          0.004995  , 0.01149814, 0.05236441]),
#   array([0.09716599, 0.03903904, 0.00212314, 0.00119617, 0.00243605,
#          0.00214362, 0.00273277, 0.02384914]),
#   array([0.10752688, 0.00847458, 0.00396825, 0.        , 0.00169205,
#          0.00314218, 0.00148883, 0.00800631])],
#  'pT2': [array([0.07692308, 0.02671756, 0.00421941, 0.00167224, 0.00235294,
#          0.0030175 , 0.00224803, 0.01029109]),
# ...

# %%
.00164069+0.00615258
# Out:
# 0.007793270000000001

# %%
0.14049587+0.00275482
# Out:
# 0.14325068999999999
